# %%
# %run DatasetUpload.ipynb
# Out:
#    Unnamed: 0  Zaman  Maxell     GP  Fujitsu  Duracell
# 0         NaN    0.0   3.307  3.301    3.287     3.238
# 1         NaN    0.0   3.307  3.301    3.287     3.238
# 2         NaN    1.0   3.307  3.301    3.287     3.240
# 3         NaN    3.0   3.112  3.035    3.091     3.071
# 4         NaN    5.0   3.066  3.015    3.051     3.039
# Unnamed: 0    6370
# Zaman          315
# Maxell         317
# GP             315
# Fujitsu          0
# Duracell       372
# dtype: int64
# Number of rows remaining: 6370
# Zaman       315
# Maxell      317
# GP          315
# Fujitsu       0
# Duracell    372
# dtype: int64
# Number of rows remaining: (6370, 5)
#       Zaman  Maxell     GP  Fujitsu  Duracell
# 0       0.0   3.307  3.301    3.287     3.238
# 1       0.0   3.307  3.301    3.287     3.238
# 2       1.0   3.307  3.301    3.287     3.240
# 3       3.0   3.112  3.035    3.091     3.071
# 4       5.0   3.066  3.015    3.051     3.039
# ...     ...     ...    ...      ...       ...
# 6365    NaN     NaN    NaN    1.804       NaN
# 6366    NaN     NaN    NaN    1.802       NaN
# 6367    NaN     NaN    NaN    1.803       NaN
# 6368    NaN     NaN    NaN    1.802       NaN
# 6369    NaN     NaN    NaN    1.800       NaN
#
# [6370 rows x 5 columns]
#
# Custom Increment for Zaman:
#         Zaman  Maxell     GP  Fujitsu  Duracell
# 0         0.0   3.307  3.301    3.287     3.238
# 1         0.0   3.307  3.301    3.287     3.238
# 2         1.0   3.307  3.301    3.287     3.240
# 3         3.0   3.112  3.035    3.091     3.071
# 4         5.0   3.066  3.015    3.051     3.039
# ...       ...     ...    ...      ...       ...
# 6365  12752.0     NaN    NaN    1.804       NaN
# 6366  12754.0     NaN    NaN    1.802       NaN
# 6367  12756.0     NaN    NaN    1.803       NaN
# 6368  12758.0     NaN    NaN    1.802       NaN
# 6369  12760.0     NaN    NaN    1.800       NaN
#
# [6370 rows x 5 columns]
# Number of NaN values: 0
# [1.         1.         1.         0.87068966 0.84018568]
# [0.32360743 0.32228117 0.32228117 0.32228117 0.32360743]
# [0.40384615 0.40318302 0.40384615 0.40450928 0.40384615]
# torch.Size([17066, 67]) torch.Size([17066])
# torch.Size([3604, 67]) torch.Size([3604])
# torch.Size([3605, 67]) torch.Size([3605])
# Batch x shape: torch.Size([32, 67])
# Batch y shape: torch.Size([32])

# %%
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np
from sklearn.preprocessing import StandardScaler
import torch.nn.functional as F
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

import seaborn as sns

from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, mean_absolute_percentage_error

# %%
PATH = 'MLP_model.pth'  # Path to the saved weights
model = torch.load(PATH, map_location=torch.device('cpu'),weights_only=False)

# Set the model to evaluation mode
model.eval()
# Out:
# SOHMode(
#   (pre_net): Linear(in_features=67, out_features=512, bias=True)
#   (backbone): MLP(
#     (net): Sequential(
#       (0): Linear(in_features=512, out_features=256, bias=True)
#       (1): ReLU()
#       (2): Dropout(p=0.2, inplace=False)
#       (3): Linear(in_features=256, out_features=128, bias=True)
#       (4): ReLU()
#     )
#     (predictor): Sequential(
#       (0): Linear(in_features=128, out_features=64, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=64, out_features=1, bias=True)
#     )
#   )
#   (mse): MSELoss()
# )

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)  # Move the model to the device
# Out:
# SOHMode(
#   (pre_net): Linear(in_features=67, out_features=512, bias=True)
#   (backbone): MLP(
#     (net): Sequential(
#       (0): Linear(in_features=512, out_features=256, bias=True)
#       (1): ReLU()
#       (2): Dropout(p=0.2, inplace=False)
#       (3): Linear(in_features=256, out_features=128, bias=True)
#       (4): ReLU()
#     )
#     (predictor): Sequential(
#       (0): Linear(in_features=128, out_features=64, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=64, out_features=1, bias=True)
#     )
#   )
#   (mse): MSELoss()
# )

# %%
def calculate_metrics_sklearn(y_true, y_pred):
    """Calculate R², MAE, MSE, and MAPE using sklearn metrics."""
    # R²
    r2 = r2_score(y_true, y_pred)

    # MAE (Mean Absolute Error)
    mae = mean_absolute_error(y_true, y_pred)

    # MSE (Mean Squared Error)
    mse = mean_squared_error(y_true, y_pred)

    # MAPE (Mean Absolute Percentage Error)
    # mape = mean_absolute_percentage_error(y_true, y_pred) * 100  # Multiply by 100 to get percentage

    return r2, mae, mse

def Train(model, train_loader, valid_loader, test_loader, args, save_folder=None):
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model = model.to(device)  # Ensure the model is on the correct device

    # Initialize optimizer and scheduler
    optimizer = torch.optim.Adam(model.parameters(), lr=args.lr)
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=args.step_size, gamma=args.gamma)

    # Define loss function
    mse_loss = torch.nn.MSELoss()

    min_loss = 10
    stop = 0
    train_losses = []
    valid_losses = []
    best_state = None

    # Store metrics for train, validation, and test
    train_r2_values = []
    valid_r2_values = []

    for e in range(1, args.n_epoch + 1):
        # --------- Train one epoch manually ---------
        model.train()
        train_loss = 0
        all_train_preds = []
        all_train_labels = []
        for data, label in train_loader:
            data, label = data.to(device), label.to(device)
            label = label.unsqueeze(1)
            pred = model(data)
            loss = mse_loss(pred, label)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            train_loss += loss.item()
            all_train_preds.append(pred.cpu().detach().numpy())
            all_train_labels.append(label.cpu().detach().numpy())

        train_loss /= len(train_loader)
        train_losses.append(train_loss)

        # Calculate metrics for training
        all_train_preds = np.concatenate(all_train_preds, axis=0)
        all_train_labels = np.concatenate(all_train_labels, axis=0)
        train_r2, train_mae,train_mse = calculate_metrics_sklearn(all_train_labels, all_train_preds)
        train_r2_values.append(train_r2)

        scheduler.step()

        # --------- Validation manually ---------
        model.eval()
        valid_loss = 0
        all_valid_preds = []
        all_valid_labels = []
        with torch.no_grad():
            for data, label in valid_loader:
                data, label = data.to(device), label.to(device)
                label = label.unsqueeze(1)
                pred = model(data)
                loss = mse_loss(pred, label)
                valid_loss += loss.item()

                all_valid_preds.append(pred.cpu().detach().numpy())
                all_valid_labels.append(label.cpu().detach().numpy())

        valid_loss /= len(valid_loader)
        valid_losses.append(valid_loss)

        # Calculate metrics for validation
        all_valid_preds = np.concatenate(all_valid_preds, axis=0)
        all_valid_labels = np.concatenate(all_valid_labels, axis=0)
        valid_r2, valid_mae, valid_mse = calculate_metrics_sklearn(all_valid_labels, all_valid_preds)
        valid_r2_values.append(valid_r2)

        lr = optimizer.state_dict()['param_groups'][0]['lr']
        
        # Print each epoch's training and validation results
        print(f"Epoch [{e}/{args.n_epoch}] - Train Loss: {train_loss:.5f} | Train R²: {train_r2:.5f} | Train MAE: {train_mae:.5f} | Train MSE: {train_mse:.5f}")
        print(f"             - Valid Loss: {valid_loss:.5f} | Valid R²: {valid_r2:.5f} | Valid MAE: {valid_mae:.5f} | Valid MSE: {valid_mse:.5f}")
    
        
        if e % 10 == 0:
            print()  # Newline every 10 epochs for clarity

        # --------- Save best model ---------
        if valid_loss < min_loss:
            best_state = model.state_dict()
            min_loss = valid_loss
            stop = 0
        else: stop += 1
        # --------- Early stopping ---------
        if stop >= args.early_stop:
            print("\nEarly stopping triggered.")
            break

    # --------- After all epochs, evaluate on test set ---------
    test_loss = 0
    all_test_preds = []
    all_test_labels = []
    with torch.no_grad():
        for data, label in test_loader:
            data, label = data.to(device), label.to(device)
            label = label.unsqueeze(1)
            pred = model(data)
            loss = mse_loss(pred, label)
            test_loss += loss.item()

            all_test_preds.append(pred.cpu().detach().numpy())
            all_test_labels.append(label.cpu().detach().numpy())

    test_loss /= len(test_loader)

    # Flatten the predictions and labels for metric calculations
    all_test_preds = np.concatenate(all_test_preds, axis=0)
    all_test_labels = np.concatenate(all_test_labels, axis=0)
    
    # Calculate metrics for test set
    test_r2, test_mae, test_mse = calculate_metrics_sklearn(all_test_labels, all_test_preds)

    # Print test results at the end of training
    print(f"Final Test Loss: {test_loss:.5f}, Test R²: {test_r2:.5f}, Test MAE: {test_mae:.5f}, Test MSE: {test_mse:.5f}")

    # --------- Save model ---------
    # if save_folder is not None and best_state is not None:
    #     torch.save(best_state, save_folder + '/best_model.pth')

    return train_losses, valid_losses, train_r2_values, valid_r2_values, test_loss, test_r2,all_test_labels, all_test_preds

# %%
class Args:
    n_epoch = 100
    lr = 0.0001
    step_size = 30
    gamma = 0.5
    early_stop = 10

args = Args()
train_losses, valid_losses, train_r2_values, valid_r2_values, test_loss, test_r2,all_test_labels, all_test_preds = Train(model, train_loader, val_loader, test_loader, args, save_folder="my_models")
# Out:
# Epoch [1/100] - Train Loss: 0.01981 | Train R²: -0.30033 | Train MAE: 0.09582 | Train MSE: 0.01984
#              - Valid Loss: 0.02187 | Valid R²: 0.07160 | Valid MAE: 0.12357 | Valid MSE: 0.02193
# Epoch [2/100] - Train Loss: 0.01300 | Train R²: 0.14680 | Train MAE: 0.05339 | Train MSE: 0.01302
#              - Valid Loss: 0.02140 | Valid R²: 0.09151 | Valid MAE: 0.12452 | Valid MSE: 0.02146
# Epoch [3/100] - Train Loss: 0.00926 | Train R²: 0.39233 | Train MAE: 0.05451 | Train MSE: 0.00927
#              - Valid Loss: 0.01640 | Valid R²: 0.30383 | Valid MAE: 0.10421 | Valid MSE: 0.01645
# Epoch [4/100] - Train Loss: 0.00710 | Train R²: 0.53413 | Train MAE: 0.04965 | Train MSE: 0.00711
#              - Valid Loss: 0.00848 | Valid R²: 0.63986 | Valid MAE: 0.05924 | Valid MSE: 0.00851
# Epoch [5/100] - Train Loss: 0.00263 | Train R²: 0.82767 | Train MAE: 0.02406 | Train MSE: 0.00263
#              - Valid Loss: 0.00432 | Valid R²: 0.81643 | Valid MAE: 0.03187 | Valid MSE: 0.00434
# Epoch [6/100] - Train Loss: 0.00177 | Train R²: 0.88416 | Train MAE: 0.01900 | Train MSE: 0.00177
#              - Valid Loss: 0.00388 | Valid R²: 0.83513 | Valid MAE: 0.03354 | Valid MSE: 0.00390
# Epoch [7/100] - Train Loss: 0.00197 | Train R²: 0.87084 | Train MAE: 0.02088 | Train MSE: 0.00197
#              - Valid Loss: 0.00490 | Valid R²: 0.79175 | Valid MAE: 0.03687 | Valid MSE: 0.00492
# Epoch [8/100] - Train Loss: 0.00406 | Train R²: 0.73360 | Train MAE: 0.02941 | Train MSE: 0.00406
#              - Valid Loss: 0.01794 | Valid R²: 0.23914 | Valid MAE: 0.11133 | Valid MSE: 0.01798
# Epoch [9/100] - Train Loss: 0.01105 | Train R²: 0.27489 | Train MAE: 0.05791 | Train MSE: 0.01106
#              - Valid Loss: 0.01593 | Valid R²: 0.32362 | Valid MAE: 0.10238 | Valid MSE: 0.01598
# Epoch [10/100] - Train Loss: 0.00611 | Train R²: 0.59890 | Train MAE: 0.04316 | Train MSE: 0.00612
#              - Valid Loss: 0.01167 | Valid R²: 0.50466 | Valid MAE: 0.08703 | Valid MSE: 0.01170
#
# Epoch [11/100] - Train Loss: 0.00495 | Train R²: 0.67519 | Train MAE: 0.03666 | Train MSE: 0.00496
#              - Valid Loss: 0.01044 | Valid R²: 0.55689 | Valid MAE: 0.08185 | Valid MSE: 0.01047
# Epoch [12/100] - Train Loss: 0.00493 | Train R²: 0.67623 | Train MAE: 0.03541 | Train MSE: 0.00494
#              - Valid Loss: 0.00944 | Valid R²: 0.59925 | Valid MAE: 0.07660 | Valid MSE: 0.00947
# Epoch [13/100] - Train Loss: 0.00541 | Train R²: 0.64530 | Train MAE: 0.04242 | Train MSE: 0.00541
#              - Valid Loss: 0.00724 | Valid R²: 0.69246 | Valid MAE: 0.06563 | Valid MSE: 0.00727
# Epoch [14/100] - Train Loss: 0.00404 | Train R²: 0.73505 | Train MAE: 0.03522 | Train MSE: 0.00404
#              - Valid Loss: 0.00678 | Valid R²: 0.71214 | Valid MAE: 0.06386 | Valid MSE: 0.00680
# Epoch [15/100] - Train Loss: 0.00378 | Train R²: 0.75176 | Train MAE: 0.03337 | Train MSE: 0.00379
#              - Valid Loss: 0.00590 | Valid R²: 0.74954 | Valid MAE: 0.05856 | Valid MSE: 0.00592
# Epoch [16/100] - Train Loss: 0.00337 | Train R²: 0.77889 | Train MAE: 0.03059 | Train MSE: 0.00337
#              - Valid Loss: 0.00517 | Valid R²: 0.78056 | Valid MAE: 0.05292 | Valid MSE: 0.00518
#
# Early stopping triggered.
# Final Test Loss: 0.00070, Test R²: 0.94290, Test MAE: 0.02313, Test MSE: 0.00068

# %%
epochs = range(1, len(train_losses) + 1)

plt.figure(figsize=(14, 6))
# R² Plot
plt.subplot(1, 2, 1)
plt.plot(epochs, train_r2_values, label='Train R²', marker='o')
plt.plot(epochs, valid_r2_values, label='Valid R²', marker='o')

plt.xlabel('Epoch')
plt.ylabel('R²')
plt.title('Training, Validation, and Test R²')
plt.legend()
plt.grid(True)

# Loss Plot
plt.subplot(1, 2, 2)
plt.plot(epochs, train_losses, label='Train Loss', marker='o')
plt.plot(epochs, valid_losses, label='Valid Loss', marker='o')

plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training vs Validation Loss')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
PATH = 'MLP_model.pth'  # Path to the saved weights
model = torch.load(PATH, map_location=torch.device('cpu'),weights_only=False)

# Set the model to evaluation mode
model.eval()
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)  # Move the model to the device
# Out:
# SOHMode(
#   (pre_net): Linear(in_features=67, out_features=512, bias=True)
#   (backbone): MLP(
#     (net): Sequential(
#       (0): Linear(in_features=512, out_features=256, bias=True)
#       (1): ReLU()
#       (2): Dropout(p=0.2, inplace=False)
#       (3): Linear(in_features=256, out_features=128, bias=True)
#       (4): ReLU()
#     )
#     (predictor): Sequential(
#       (0): Linear(in_features=128, out_features=64, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=64, out_features=1, bias=True)
#     )
#   )
#   (mse): MSELoss()
# )

# %%
for name, param in model.named_parameters():
    if 'predictor' not in name:  # This checks if the parameter is not in the 'predictor' layer
        param.requires_grad = False
    else:
        param.requires_grad = True  # Allow the last layer to be trainable

# %%
class Args:
    n_epoch = 100
    lr = 0.0001
    step_size = 30
    gamma = 0.5
    early_stop = 10

args = Args()
train_losses, valid_losses, train_r2_values, valid_r2_values, test_loss, test_r2,all_test_labels, all_test_preds = Train(model, train_loader, val_loader, test_loader, args)
# Out:
# Epoch [1/100] - Train Loss: 0.02781 | Train R²: -0.82445 | Train MAE: 0.13954 | Train MSE: 0.02784
#              - Valid Loss: 0.02569 | Valid R²: -0.09110 | Valid MAE: 0.11292 | Valid MSE: 0.02578
# Epoch [2/100] - Train Loss: 0.01591 | Train R²: -0.04337 | Train MAE: 0.09637 | Train MSE: 0.01592
#              - Valid Loss: 0.02570 | Valid R²: -0.09153 | Valid MAE: 0.11289 | Valid MSE: 0.02579
# Epoch [3/100] - Train Loss: 0.01581 | Train R²: -0.03719 | Train MAE: 0.09547 | Train MSE: 0.01582
#              - Valid Loss: 0.02562 | Valid R²: -0.08779 | Valid MAE: 0.11316 | Valid MSE: 0.02570
# Epoch [4/100] - Train Loss: 0.01578 | Train R²: -0.03506 | Train MAE: 0.09514 | Train MSE: 0.01579
#              - Valid Loss: 0.02554 | Valid R²: -0.08465 | Valid MAE: 0.11342 | Valid MSE: 0.02563
# Epoch [5/100] - Train Loss: 0.01577 | Train R²: -0.03436 | Train MAE: 0.09512 | Train MSE: 0.01578
#              - Valid Loss: 0.02551 | Valid R²: -0.08347 | Valid MAE: 0.11353 | Valid MSE: 0.02560
# Epoch [6/100] - Train Loss: 0.01579 | Train R²: -0.03581 | Train MAE: 0.09534 | Train MSE: 0.01580
#              - Valid Loss: 0.02549 | Valid R²: -0.08246 | Valid MAE: 0.11363 | Valid MSE: 0.02557
# Epoch [7/100] - Train Loss: 0.01580 | Train R²: -0.03645 | Train MAE: 0.09562 | Train MSE: 0.01581
#              - Valid Loss: 0.02552 | Valid R²: -0.08359 | Valid MAE: 0.11355 | Valid MSE: 0.02560
# Epoch [8/100] - Train Loss: 0.01583 | Train R²: -0.03824 | Train MAE: 0.09604 | Train MSE: 0.01584
#              - Valid Loss: 0.02554 | Valid R²: -0.08447 | Valid MAE: 0.11349 | Valid MSE: 0.02562
# Epoch [9/100] - Train Loss: 0.01586 | Train R²: -0.04035 | Train MAE: 0.09645 | Train MSE: 0.01587
#              - Valid Loss: 0.02555 | Valid R²: -0.08512 | Valid MAE: 0.11346 | Valid MSE: 0.02564
# Epoch [10/100] - Train Loss: 0.01589 | Train R²: -0.04253 | Train MAE: 0.09689 | Train MSE: 0.01591
#              - Valid Loss: 0.02556 | Valid R²: -0.08546 | Valid MAE: 0.11345 | Valid MSE: 0.02565
#
# Epoch [11/100] - Train Loss: 0.01590 | Train R²: -0.04324 | Train MAE: 0.09724 | Train MSE: 0.01592
#              - Valid Loss: 0.02554 | Valid R²: -0.08471 | Valid MAE: 0.11352 | Valid MSE: 0.02563
# Epoch [12/100] - Train Loss: 0.01595 | Train R²: -0.04599 | Train MAE: 0.09761 | Train MSE: 0.01596
#              - Valid Loss: 0.02551 | Valid R²: -0.08350 | Valid MAE: 0.11364 | Valid MSE: 0.02560
# Epoch [13/100] - Train Loss: 0.01598 | Train R²: -0.04811 | Train MAE: 0.09790 | Train MSE: 0.01599
#              - Valid Loss: 0.02546 | Valid R²: -0.08117 | Valid MAE: 0.11384 | Valid MSE: 0.02554
# Epoch [14/100] - Train Loss: 0.01600 | Train R²: -0.04976 | Train MAE: 0.09811 | Train MSE: 0.01602
#              - Valid Loss: 0.02541 | Valid R²: -0.07897 | Valid MAE: 0.11405 | Valid MSE: 0.02549
# Epoch [15/100] - Train Loss: 0.01602 | Train R²: -0.05078 | Train MAE: 0.09831 | Train MSE: 0.01603
#              - Valid Loss: 0.02536 | Valid R²: -0.07675 | Valid MAE: 0.11425 | Valid MSE: 0.02544
# Epoch [16/100] - Train Loss: 0.01600 | Train R²: -0.04986 | Train MAE: 0.09830 | Train MSE: 0.01602
#              - Valid Loss: 0.02531 | Valid R²: -0.07473 | Valid MAE: 0.11443 | Valid MSE: 0.02539
# Epoch [17/100] - Train Loss: 0.01605 | Train R²: -0.05308 | Train MAE: 0.09855 | Train MSE: 0.01607
#              - Valid Loss: 0.02526 | Valid R²: -0.07272 | Valid MAE: 0.11462 | Valid MSE: 0.02534
# Epoch [18/100] - Train Loss: 0.01609 | Train R²: -0.05525 | Train MAE: 0.09875 | Train MSE: 0.01610
#              - Valid Loss: 0.02521 | Valid R²: -0.07072 | Valid MAE: 0.11480 | Valid MSE: 0.02530
# Epoch [19/100] - Train Loss: 0.01599 | Train R²: -0.04863 | Train MAE: 0.09842 | Train MSE: 0.01600
#              - Valid Loss: 0.02516 | Valid R²: -0.06850 | Valid MAE: 0.11502 | Valid MSE: 0.02524
# Epoch [20/100] - Train Loss: 0.01611 | Train R²: -0.05683 | Train MAE: 0.09890 | Train MSE: 0.01612
#              - Valid Loss: 0.02514 | Valid R²: -0.06759 | Valid MAE: 0.11511 | Valid MSE: 0.02522
#
# Epoch [21/100] - Train Loss: 0.01610 | Train R²: -0.05603 | Train MAE: 0.09882 | Train MSE: 0.01611
#              - Valid Loss: 0.02526 | Valid R²: -0.07264 | Valid MAE: 0.11462 | Valid MSE: 0.02534
# Epoch [22/100] - Train Loss: 0.01598 | Train R²: -0.04838 | Train MAE: 0.09845 | Train MSE: 0.01599
#              - Valid Loss: 0.02508 | Valid R²: -0.06522 | Valid MAE: 0.11533 | Valid MSE: 0.02517
# Epoch [23/100] - Train Loss: 0.01611 | Train R²: -0.05702 | Train MAE: 0.09898 | Train MSE: 0.01613
#              - Valid Loss: 0.02507 | Valid R²: -0.06460 | Valid MAE: 0.11539 | Valid MSE: 0.02515
# Epoch [24/100] - Train Loss: 0.01613 | Train R²: -0.05789 | Train MAE: 0.09901 | Train MSE: 0.01614
#              - Valid Loss: 0.02505 | Valid R²: -0.06393 | Valid MAE: 0.11545 | Valid MSE: 0.02514
# Epoch [25/100] - Train Loss: 0.01604 | Train R²: -0.05247 | Train MAE: 0.09881 | Train MSE: 0.01606
#              - Valid Loss: 0.02502 | Valid R²: -0.06269 | Valid MAE: 0.11557 | Valid MSE: 0.02511
# Epoch [26/100] - Train Loss: 0.01601 | Train R²: -0.05011 | Train MAE: 0.09867 | Train MSE: 0.01602
#              - Valid Loss: 0.02496 | Valid R²: -0.05994 | Valid MAE: 0.11586 | Valid MSE: 0.02504
# Epoch [27/100] - Train Loss: 0.01612 | Train R²: -0.05734 | Train MAE: 0.09905 | Train MSE: 0.01613
#              - Valid Loss: 0.02498 | Valid R²: -0.06073 | Valid MAE: 0.11577 | Valid MSE: 0.02506
# Epoch [28/100] - Train Loss: 0.01611 | Train R²: -0.05705 | Train MAE: 0.09901 | Train MSE: 0.01613
#              - Valid Loss: 0.02496 | Valid R²: -0.06006 | Valid MAE: 0.11584 | Valid MSE: 0.02505
# Epoch [29/100] - Train Loss: 0.01613 | Train R²: -0.05841 | Train MAE: 0.09904 | Train MSE: 0.01615
#              - Valid Loss: 0.02496 | Valid R²: -0.05997 | Valid MAE: 0.11585 | Valid MSE: 0.02504
# Epoch [30/100] - Train Loss: 0.01614 | Train R²: -0.05860 | Train MAE: 0.09906 | Train MSE: 0.01615
#              - Valid Loss: 0.02495 | Valid R²: -0.05951 | Valid MAE: 0.11589 | Valid MSE: 0.02503
#
# Epoch [31/100] - Train Loss: 0.01597 | Train R²: -0.04748 | Train MAE: 0.09804 | Train MSE: 0.01598
#              - Valid Loss: 0.02499 | Valid R²: -0.06139 | Valid MAE: 0.11568 | Valid MSE: 0.02508
# Epoch [32/100] - Train Loss: 0.01599 | Train R²: -0.04899 | Train MAE: 0.09812 | Train MSE: 0.01600
#              - Valid Loss: 0.02475 | Valid R²: -0.05123 | Valid MAE: 0.11681 | Valid MSE: 0.02484
# Epoch [33/100] - Train Loss: 0.01602 | Train R²: -0.05070 | Train MAE: 0.09854 | Train MSE: 0.01603
#              - Valid Loss: 0.02475 | Valid R²: -0.05084 | Valid MAE: 0.11686 | Valid MSE: 0.02483
# Epoch [34/100] - Train Loss: 0.01601 | Train R²: -0.05038 | Train MAE: 0.09854 | Train MSE: 0.01603
#              - Valid Loss: 0.02475 | Valid R²: -0.05082 | Valid MAE: 0.11686 | Valid MSE: 0.02483
# Epoch [35/100] - Train Loss: 0.01601 | Train R²: -0.05058 | Train MAE: 0.09853 | Train MSE: 0.01603
#              - Valid Loss: 0.02474 | Valid R²: -0.05080 | Valid MAE: 0.11686 | Valid MSE: 0.02483
# Epoch [36/100] - Train Loss: 0.01602 | Train R²: -0.05093 | Train MAE: 0.09861 | Train MSE: 0.01603
#              - Valid Loss: 0.02472 | Valid R²: -0.04962 | Valid MAE: 0.11699 | Valid MSE: 0.02480
# Epoch [37/100] - Train Loss: 0.01601 | Train R²: -0.05036 | Train MAE: 0.09864 | Train MSE: 0.01603
#              - Valid Loss: 0.02472 | Valid R²: -0.04971 | Valid MAE: 0.11698 | Valid MSE: 0.02480
# Epoch [38/100] - Train Loss: 0.01595 | Train R²: -0.04636 | Train MAE: 0.09814 | Train MSE: 0.01596
#              - Valid Loss: 0.02524 | Valid R²: -0.07193 | Valid MAE: 0.11463 | Valid MSE: 0.02533
# Epoch [39/100] - Train Loss: 0.01598 | Train R²: -0.04850 | Train MAE: 0.09790 | Train MSE: 0.01600
#              - Valid Loss: 0.02476 | Valid R²: -0.05163 | Valid MAE: 0.11675 | Valid MSE: 0.02485
# Epoch [40/100] - Train Loss: 0.01602 | Train R²: -0.05094 | Train MAE: 0.09855 | Train MSE: 0.01603
#              - Valid Loss: 0.02474 | Valid R²: -0.05059 | Valid MAE: 0.11687 | Valid MSE: 0.02482
#
# Epoch [41/100] - Train Loss: 0.01601 | Train R²: -0.05054 | Train MAE: 0.09859 | Train MSE: 0.01603
#              - Valid Loss: 0.02474 | Valid R²: -0.05057 | Valid MAE: 0.11687 | Valid MSE: 0.02482
# Epoch [42/100] - Train Loss: 0.01602 | Train R²: -0.05121 | Train MAE: 0.09861 | Train MSE: 0.01604
#              - Valid Loss: 0.02474 | Valid R²: -0.05060 | Valid MAE: 0.11686 | Valid MSE: 0.02482
# Epoch [43/100] - Train Loss: 0.01601 | Train R²: -0.05062 | Train MAE: 0.09857 | Train MSE: 0.01603
#              - Valid Loss: 0.02474 | Valid R²: -0.05059 | Valid MAE: 0.11686 | Valid MSE: 0.02482
# Epoch [44/100] - Train Loss: 0.01602 | Train R²: -0.05093 | Train MAE: 0.09859 | Train MSE: 0.01603
#              - Valid Loss: 0.02474 | Valid R²: -0.05049 | Valid MAE: 0.11687 | Valid MSE: 0.02482
# Epoch [45/100] - Train Loss: 0.01601 | Train R²: -0.05050 | Train MAE: 0.09853 | Train MSE: 0.01603
#              - Valid Loss: 0.02474 | Valid R²: -0.05043 | Valid MAE: 0.11687 | Valid MSE: 0.02482
# Epoch [46/100] - Train Loss: 0.01601 | Train R²: -0.05026 | Train MAE: 0.09853 | Train MSE: 0.01602
#              - Valid Loss: 0.02474 | Valid R²: -0.05041 | Valid MAE: 0.11687 | Valid MSE: 0.02482
#
# Early stopping triggered.
# Final Test Loss: 0.02835, Test R²: -1.34186, Test MAE: 0.12643, Test MSE: 0.02797

# %%
epochs = range(1, len(train_losses) + 1)

plt.figure(figsize=(14, 6))
# R² Plot
plt.subplot(1, 2, 1)
plt.plot(epochs, train_r2_values, label='Train R²', marker='o')
plt.plot(epochs, valid_r2_values, label='Valid R²', marker='o')

plt.xlabel('Epoch')
plt.ylabel('R²')
plt.title('Training, Validation, and Test R²')
plt.legend()
plt.grid(True)

# Loss Plot
plt.subplot(1, 2, 2)
plt.plot(epochs, train_losses, label='Train Loss', marker='o')
plt.plot(epochs, valid_losses, label='Valid Loss', marker='o')

plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training vs Validation Loss')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# mlp not working good with freezing because:
#
# Simpler Structure: MLPs lack the deep, hierarchical feature extraction of CNNs, so freezing layers can limit the flexibility and ability of the model to adjust to new tasks.
#
# Fully Connected Layers: In MLPs, every node in a layer is connected to every node in the next layer, leading to a high number of parameters. Freezing parts of the network can restrict how well the model adapts to new data, especially in terms of generalization.
