# %%
# %run DatasetUpload.ipynb
# Out:
#    Unnamed: 0  Zaman  Maxell     GP  Fujitsu  Duracell
# 0         NaN    0.0   3.307  3.301    3.287     3.238
# 1         NaN    0.0   3.307  3.301    3.287     3.238
# 2         NaN    1.0   3.307  3.301    3.287     3.240
# 3         NaN    3.0   3.112  3.035    3.091     3.071
# 4         NaN    5.0   3.066  3.015    3.051     3.039
# Unnamed: 0    6370
# Zaman          315
# Maxell         317
# GP             315
# Fujitsu          0
# Duracell       372
# dtype: int64
# Number of rows remaining: 6370
# Zaman       315
# Maxell      317
# GP          315
# Fujitsu       0
# Duracell    372
# dtype: int64
# Number of rows remaining: (6370, 5)
#       Zaman  Maxell     GP  Fujitsu  Duracell
# 0       0.0   3.307  3.301    3.287     3.238
# 1       0.0   3.307  3.301    3.287     3.238
# 2       1.0   3.307  3.301    3.287     3.240
# 3       3.0   3.112  3.035    3.091     3.071
# 4       5.0   3.066  3.015    3.051     3.039
# ...     ...     ...    ...      ...       ...
# 6365    NaN     NaN    NaN    1.804       NaN
# 6366    NaN     NaN    NaN    1.802       NaN
# 6367    NaN     NaN    NaN    1.803       NaN
# 6368    NaN     NaN    NaN    1.802       NaN
# 6369    NaN     NaN    NaN    1.800       NaN
#
# [6370 rows x 5 columns]
#
# Custom Increment for Zaman:
#         Zaman  Maxell     GP  Fujitsu  Duracell
# 0         0.0   3.307  3.301    3.287     3.238
# 1         0.0   3.307  3.301    3.287     3.238
# 2         1.0   3.307  3.301    3.287     3.240
# 3         3.0   3.112  3.035    3.091     3.071
# 4         5.0   3.066  3.015    3.051     3.039
# ...       ...     ...    ...      ...       ...
# 6365  12752.0     NaN    NaN    1.804       NaN
# 6366  12754.0     NaN    NaN    1.802       NaN
# 6367  12756.0     NaN    NaN    1.803       NaN
# 6368  12758.0     NaN    NaN    1.802       NaN
# 6369  12760.0     NaN    NaN    1.800       NaN
#
# [6370 rows x 5 columns]
# Number of NaN values: 0
# [1.         1.         1.         0.87068966 0.84018568]
# [0.32360743 0.32228117 0.32228117 0.32228117 0.32360743]
# [0.40384615 0.40318302 0.40384615 0.40450928 0.40384615]
# torch.Size([17066, 67]) torch.Size([17066])
# torch.Size([3604, 67]) torch.Size([3604])
# torch.Size([3605, 67]) torch.Size([3605])
# Batch x shape: torch.Size([32, 67])
# Batch y shape: torch.Size([32])

# %%
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np
from sklearn.preprocessing import StandardScaler
import torch.nn.functional as F
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

import seaborn as sns

from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, mean_absolute_percentage_error

# %%
PATH = 'MLP_model.pth'  # Path to the saved weights
model = torch.load(PATH, map_location=torch.device('cpu'),weights_only=False)

# Set the model to evaluation mode
model.eval()
# Out:
# SOHMode(
#   (pre_net): Linear(in_features=67, out_features=512, bias=True)
#   (backbone): MLP(
#     (net): Sequential(
#       (0): Linear(in_features=512, out_features=256, bias=True)
#       (1): ReLU()
#       (2): Dropout(p=0.2, inplace=False)
#       (3): Linear(in_features=256, out_features=128, bias=True)
#       (4): ReLU()
#     )
#     (predictor): Sequential(
#       (0): Linear(in_features=128, out_features=64, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=64, out_features=1, bias=True)
#     )
#   )
#   (mse): MSELoss()
# )

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)  # Move the model to the device
# Out:
# SOHMode(
#   (pre_net): Linear(in_features=67, out_features=512, bias=True)
#   (backbone): MLP(
#     (net): Sequential(
#       (0): Linear(in_features=512, out_features=256, bias=True)
#       (1): ReLU()
#       (2): Dropout(p=0.2, inplace=False)
#       (3): Linear(in_features=256, out_features=128, bias=True)
#       (4): ReLU()
#     )
#     (predictor): Sequential(
#       (0): Linear(in_features=128, out_features=64, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=64, out_features=1, bias=True)
#     )
#   )
#   (mse): MSELoss()
# )

# %%
def calculate_metrics_sklearn(y_true, y_pred):
    """Calculate R², MAE, MSE, and MAPE using sklearn metrics."""
    # R²
    r2 = r2_score(y_true, y_pred)

    # MAE (Mean Absolute Error)
    mae = mean_absolute_error(y_true, y_pred)

    # MSE (Mean Squared Error)
    mse = mean_squared_error(y_true, y_pred)

    # MAPE (Mean Absolute Percentage Error)
    # mape = mean_absolute_percentage_error(y_true, y_pred) * 100  # Multiply by 100 to get percentage

    return r2, mae, mse

def Train(model, train_loader, valid_loader, test_loader, args, save_folder=None):
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model = model.to(device)  # Ensure the model is on the correct device

    # Initialize optimizer and scheduler
    optimizer = torch.optim.Adam(model.parameters(), lr=args.lr)
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=args.step_size, gamma=args.gamma)

    # Define loss function
    mse_loss = torch.nn.MSELoss()

    min_loss = 10
    stop = 0
    train_losses = []
    valid_losses = []
    best_state = None

    # Store metrics for train, validation, and test
    train_r2_values = []
    valid_r2_values = []

    for e in range(1, args.n_epoch + 1):
        # --------- Train one epoch manually ---------
        model.train()
        train_loss = 0
        all_train_preds = []
        all_train_labels = []
        for data, label in train_loader:
            data, label = data.to(device), label.to(device)
            label = label.unsqueeze(1)
            pred = model(data)
            loss = mse_loss(pred, label)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            train_loss += loss.item()
            all_train_preds.append(pred.cpu().detach().numpy())
            all_train_labels.append(label.cpu().detach().numpy())

        train_loss /= len(train_loader)
        train_losses.append(train_loss)

        # Calculate metrics for training
        all_train_preds = np.concatenate(all_train_preds, axis=0)
        all_train_labels = np.concatenate(all_train_labels, axis=0)
        train_r2, train_mae,train_mse = calculate_metrics_sklearn(all_train_labels, all_train_preds)
        train_r2_values.append(train_r2)

        scheduler.step()

        # --------- Validation manually ---------
        model.eval()
        valid_loss = 0
        all_valid_preds = []
        all_valid_labels = []
        with torch.no_grad():
            for data, label in valid_loader:
                data, label = data.to(device), label.to(device)
                label = label.unsqueeze(1)
                pred = model(data)
                loss = mse_loss(pred, label)
                valid_loss += loss.item()

                all_valid_preds.append(pred.cpu().detach().numpy())
                all_valid_labels.append(label.cpu().detach().numpy())

        valid_loss /= len(valid_loader)
        valid_losses.append(valid_loss)

        # Calculate metrics for validation
        all_valid_preds = np.concatenate(all_valid_preds, axis=0)
        all_valid_labels = np.concatenate(all_valid_labels, axis=0)
        valid_r2, valid_mae, valid_mse = calculate_metrics_sklearn(all_valid_labels, all_valid_preds)
        valid_r2_values.append(valid_r2)

        lr = optimizer.state_dict()['param_groups'][0]['lr']
        
        # Print each epoch's training and validation results
        print(f"Epoch [{e}/{args.n_epoch}] - Train Loss: {train_loss:.5f} | Train R²: {train_r2:.5f} | Train MAE: {train_mae:.5f} | Train MSE: {train_mse:.5f}")
        print(f"             - Valid Loss: {valid_loss:.5f} | Valid R²: {valid_r2:.5f} | Valid MAE: {valid_mae:.5f} | Valid MSE: {valid_mse:.5f}")
    
        
        if e % 10 == 0:
            print()  # Newline every 10 epochs for clarity

        # --------- Save best model ---------
        delta = 1e-3 
        # --------- Save best model ---------
        if valid_loss < min_loss - delta:
            best_state = model.state_dict()
            min_loss = valid_loss
            stop = 0
        else: stop += 1
        # --------- Early stopping ---------
        if stop >= args.early_stop:
            print("\nEarly stopping triggered.")
            break

    # --------- After all epochs, evaluate on test set ---------
    test_loss = 0
    all_test_preds = []
    all_test_labels = []
    with torch.no_grad():
        for data, label in test_loader:
            data, label = data.to(device), label.to(device)
            label = label.unsqueeze(1)
            pred = model(data)
            loss = mse_loss(pred, label)
            test_loss += loss.item()

            all_test_preds.append(pred.cpu().detach().numpy())
            all_test_labels.append(label.cpu().detach().numpy())

    test_loss /= len(test_loader)

    # Flatten the predictions and labels for metric calculations
    all_test_preds = np.concatenate(all_test_preds, axis=0)
    all_test_labels = np.concatenate(all_test_labels, axis=0)
    
    # Calculate metrics for test set
    test_r2, test_mae, test_mse = calculate_metrics_sklearn(all_test_labels, all_test_preds)

    # Print test results at the end of training
    print(f"Final Test Loss: {test_loss:.5f}, Test R²: {test_r2:.5f}, Test MAE: {test_mae:.5f}, Test MSE: {test_mse:.5f}")

    # --------- Save model ---------
    # if save_folder is not None and best_state is not None:
    #     torch.save(best_state, save_folder + '/best_model.pth')

    return train_losses, valid_losses, train_r2_values, valid_r2_values, test_loss, test_r2,all_test_labels, all_test_preds

# %%
class Args:
    n_epoch = 100
    lr = 0.0001
    step_size = 30
    gamma = 0.5
    early_stop = 10

args = Args()
train_losses, valid_losses, train_r2_values, valid_r2_values, test_loss, test_r2,all_test_labels, all_test_preds = Train(model, train_loader, val_loader, test_loader, args, save_folder="my_models")
# Out:
# Epoch [1/100] - Train Loss: 0.01981 | Train R²: -0.29992 | Train MAE: 0.09702 | Train MSE: 0.01983
#              - Valid Loss: 0.02052 | Valid R²: 0.12876 | Valid MAE: 0.11643 | Valid MSE: 0.02058
# Epoch [2/100] - Train Loss: 0.03493 | Train R²: -1.29210 | Train MAE: 0.11183 | Train MSE: 0.03497
#              - Valid Loss: 0.02120 | Valid R²: 0.10032 | Valid MAE: 0.12336 | Valid MSE: 0.02126
# Epoch [3/100] - Train Loss: 0.01216 | Train R²: 0.20232 | Train MAE: 0.05764 | Train MSE: 0.01217
#              - Valid Loss: 0.01320 | Valid R²: 0.43949 | Valid MAE: 0.09238 | Valid MSE: 0.01324
# Epoch [4/100] - Train Loss: 0.00669 | Train R²: 0.56122 | Train MAE: 0.04706 | Train MSE: 0.00669
#              - Valid Loss: 0.00958 | Valid R²: 0.59343 | Valid MAE: 0.07615 | Valid MSE: 0.00961
# Epoch [5/100] - Train Loss: 0.00537 | Train R²: 0.64781 | Train MAE: 0.04151 | Train MSE: 0.00537
#              - Valid Loss: 0.00746 | Valid R²: 0.68328 | Valid MAE: 0.06570 | Valid MSE: 0.00748
# Epoch [6/100] - Train Loss: 0.00417 | Train R²: 0.72648 | Train MAE: 0.03561 | Train MSE: 0.00417
#              - Valid Loss: 0.00577 | Valid R²: 0.75490 | Valid MAE: 0.05607 | Valid MSE: 0.00579
# Epoch [7/100] - Train Loss: 0.00325 | Train R²: 0.78678 | Train MAE: 0.02986 | Train MSE: 0.00325
#              - Valid Loss: 0.00487 | Valid R²: 0.79332 | Valid MAE: 0.04923 | Valid MSE: 0.00488
# Epoch [8/100] - Train Loss: 0.00271 | Train R²: 0.82240 | Train MAE: 0.02637 | Train MSE: 0.00271
#              - Valid Loss: 0.00465 | Valid R²: 0.80283 | Valid MAE: 0.04903 | Valid MSE: 0.00466
# Epoch [9/100] - Train Loss: 0.00229 | Train R²: 0.84987 | Train MAE: 0.02443 | Train MSE: 0.00229
#              - Valid Loss: 0.00415 | Valid R²: 0.82402 | Valid MAE: 0.04562 | Valid MSE: 0.00416
# Epoch [10/100] - Train Loss: 0.00217 | Train R²: 0.85757 | Train MAE: 0.02416 | Train MSE: 0.00217
#              - Valid Loss: 0.00378 | Valid R²: 0.83955 | Valid MAE: 0.04347 | Valid MSE: 0.00379
#
# Epoch [11/100] - Train Loss: 0.00185 | Train R²: 0.87850 | Train MAE: 0.02216 | Train MSE: 0.00185
#              - Valid Loss: 0.00354 | Valid R²: 0.84996 | Valid MAE: 0.04171 | Valid MSE: 0.00354
# Epoch [12/100] - Train Loss: 0.00161 | Train R²: 0.89444 | Train MAE: 0.02028 | Train MSE: 0.00161
#              - Valid Loss: 0.00339 | Valid R²: 0.85611 | Valid MAE: 0.04042 | Valid MSE: 0.00340
# Epoch [13/100] - Train Loss: 0.00140 | Train R²: 0.90795 | Train MAE: 0.01851 | Train MSE: 0.00140
#              - Valid Loss: 0.00344 | Valid R²: 0.85392 | Valid MAE: 0.04017 | Valid MSE: 0.00345
# Epoch [14/100] - Train Loss: 0.00128 | Train R²: 0.91608 | Train MAE: 0.01705 | Train MSE: 0.00128
#              - Valid Loss: 0.00370 | Valid R²: 0.84311 | Valid MAE: 0.04108 | Valid MSE: 0.00371
# Epoch [15/100] - Train Loss: 0.00121 | Train R²: 0.92028 | Train MAE: 0.01713 | Train MSE: 0.00122
#              - Valid Loss: 0.00292 | Valid R²: 0.87616 | Valid MAE: 0.03621 | Valid MSE: 0.00293
# Epoch [16/100] - Train Loss: 0.00124 | Train R²: 0.91855 | Train MAE: 0.01798 | Train MSE: 0.00124
#              - Valid Loss: 0.00271 | Valid R²: 0.88483 | Valid MAE: 0.03416 | Valid MSE: 0.00272
# Epoch [17/100] - Train Loss: 0.00113 | Train R²: 0.92552 | Train MAE: 0.01630 | Train MSE: 0.00114
#              - Valid Loss: 0.00271 | Valid R²: 0.88502 | Valid MAE: 0.03700 | Valid MSE: 0.00272
# Epoch [18/100] - Train Loss: 0.00118 | Train R²: 0.92284 | Train MAE: 0.01711 | Train MSE: 0.00118
#              - Valid Loss: 0.00342 | Valid R²: 0.85474 | Valid MAE: 0.04374 | Valid MSE: 0.00343
# Epoch [19/100] - Train Loss: 0.00124 | Train R²: 0.91892 | Train MAE: 0.01743 | Train MSE: 0.00124
#              - Valid Loss: 0.00311 | Valid R²: 0.86787 | Valid MAE: 0.04355 | Valid MSE: 0.00312
# Epoch [20/100] - Train Loss: 0.00113 | Train R²: 0.92572 | Train MAE: 0.01690 | Train MSE: 0.00113
#              - Valid Loss: 0.00404 | Valid R²: 0.82868 | Valid MAE: 0.05060 | Valid MSE: 0.00405
#
# Epoch [21/100] - Train Loss: 0.00126 | Train R²: 0.91735 | Train MAE: 0.01935 | Train MSE: 0.00126
#              - Valid Loss: 0.00259 | Valid R²: 0.88996 | Valid MAE: 0.04103 | Valid MSE: 0.00260
#
# Early stopping triggered.
# Final Test Loss: 0.00086, Test R²: 0.92943, Test MAE: 0.02399, Test MSE: 0.00084

# %%
epochs = range(1, len(train_losses) + 1)

plt.figure(figsize=(14, 6))
# R² Plot
plt.subplot(1, 2, 1)
plt.plot(epochs, train_r2_values, label='Train R²', marker='o')
plt.plot(epochs, valid_r2_values, label='Valid R²', marker='o')

plt.xlabel('Epoch')
plt.ylabel('R²')
plt.title('Training, Validation, and Test R²')
plt.legend()
plt.grid(True)

# Loss Plot
plt.subplot(1, 2, 2)
plt.plot(epochs, train_losses, label='Train Loss', marker='o')
plt.plot(epochs, valid_losses, label='Valid Loss', marker='o')

plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training vs Validation Loss')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
PATH = 'MLP_model.pth'  # Path to the saved weights
model = torch.load(PATH, map_location=torch.device('cpu'),weights_only=False)

# Set the model to evaluation mode
model.eval()
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)  # Move the model to the device
# Out:
# SOHMode(
#   (pre_net): Linear(in_features=67, out_features=512, bias=True)
#   (backbone): MLP(
#     (net): Sequential(
#       (0): Linear(in_features=512, out_features=256, bias=True)
#       (1): ReLU()
#       (2): Dropout(p=0.2, inplace=False)
#       (3): Linear(in_features=256, out_features=128, bias=True)
#       (4): ReLU()
#     )
#     (predictor): Sequential(
#       (0): Linear(in_features=128, out_features=64, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=64, out_features=1, bias=True)
#     )
#   )
#   (mse): MSELoss()
# )

# %%
for name, param in model.named_parameters():
    if 'predictor' not in name:  # This checks if the parameter is not in the 'predictor' layer
        param.requires_grad = False
    else:
        param.requires_grad = True  # Allow the last layer to be trainable

# %%
class Args:
    n_epoch = 100
    lr = 0.001
    step_size = 30
    gamma = 0.5
    early_stop = 10

args = Args()
train_losses, valid_losses, train_r2_values, valid_r2_values, test_loss, test_r2,all_test_labels, all_test_preds = Train(model, train_loader, val_loader, test_loader, args)
# Out:
# Epoch [1/100] - Train Loss: 0.01403 | Train R²: 0.07916 | Train MAE: 0.06323 | Train MSE: 0.01405
#              - Valid Loss: 0.02398 | Valid R²: -0.01812 | Valid MAE: 0.12413 | Valid MSE: 0.02405
# Epoch [2/100] - Train Loss: 0.01385 | Train R²: 0.09100 | Train MAE: 0.07199 | Train MSE: 0.01387
#              - Valid Loss: 0.02397 | Valid R²: -0.01765 | Valid MAE: 0.12343 | Valid MSE: 0.02404
# Epoch [3/100] - Train Loss: 0.01392 | Train R²: 0.08692 | Train MAE: 0.07350 | Train MSE: 0.01393
#              - Valid Loss: 0.02396 | Valid R²: -0.01724 | Valid MAE: 0.12286 | Valid MSE: 0.02403
# Epoch [4/100] - Train Loss: 0.01401 | Train R²: 0.08051 | Train MAE: 0.07485 | Train MSE: 0.01403
#              - Valid Loss: 0.02395 | Valid R²: -0.01687 | Valid MAE: 0.12235 | Valid MSE: 0.02402
# Epoch [5/100] - Train Loss: 0.01412 | Train R²: 0.07351 | Train MAE: 0.07621 | Train MSE: 0.01414
#              - Valid Loss: 0.02394 | Valid R²: -0.01652 | Valid MAE: 0.12186 | Valid MSE: 0.02402
# Epoch [6/100] - Train Loss: 0.01425 | Train R²: 0.06495 | Train MAE: 0.07766 | Train MSE: 0.01427
#              - Valid Loss: 0.02394 | Valid R²: -0.01643 | Valid MAE: 0.12132 | Valid MSE: 0.02401
# Epoch [7/100] - Train Loss: 0.01440 | Train R²: 0.05537 | Train MAE: 0.07929 | Train MSE: 0.01441
#              - Valid Loss: 0.02394 | Valid R²: -0.01666 | Valid MAE: 0.12073 | Valid MSE: 0.02402
# Epoch [8/100] - Train Loss: 0.01456 | Train R²: 0.04465 | Train MAE: 0.08119 | Train MSE: 0.01458
#              - Valid Loss: 0.02396 | Valid R²: -0.01732 | Valid MAE: 0.12006 | Valid MSE: 0.02404
# Epoch [9/100] - Train Loss: 0.01476 | Train R²: 0.03189 | Train MAE: 0.08345 | Train MSE: 0.01477
#              - Valid Loss: 0.02400 | Valid R²: -0.01926 | Valid MAE: 0.11918 | Valid MSE: 0.02408
# Epoch [10/100] - Train Loss: 0.01499 | Train R²: 0.01667 | Train MAE: 0.08621 | Train MSE: 0.01500
#              - Valid Loss: 0.02410 | Valid R²: -0.02326 | Valid MAE: 0.11802 | Valid MSE: 0.02418
#
# Epoch [11/100] - Train Loss: 0.01526 | Train R²: -0.00113 | Train MAE: 0.08967 | Train MSE: 0.01527
#              - Valid Loss: 0.02432 | Valid R²: -0.03271 | Valid MAE: 0.11625 | Valid MSE: 0.02440
#
# Early stopping triggered.
# Final Test Loss: 0.02764, Test R²: -1.28284, Test MAE: 0.12457, Test MSE: 0.02726

# %%
epochs = range(1, len(train_losses) + 1)

plt.figure(figsize=(14, 6))
# R² Plot
plt.subplot(1, 2, 1)
plt.plot(epochs, train_r2_values, label='Train R²', marker='o')
plt.plot(epochs, valid_r2_values, label='Valid R²', marker='o')

plt.xlabel('Epoch')
plt.ylabel('R²')
plt.title('Training, Validation, and Test R²')
plt.legend()
plt.grid(True)

# Loss Plot
plt.subplot(1, 2, 2)
plt.plot(epochs, train_losses, label='Train Loss', marker='o')
plt.plot(epochs, valid_losses, label='Valid Loss', marker='o')

plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training vs Validation Loss')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# mlp not working good with freezing because:
#
# Simpler Structure: MLPs lack the deep, hierarchical feature extraction of CNNs, so freezing layers can limit the flexibility and ability of the model to adjust to new tasks.
#
# Fully Connected Layers: In MLPs, every node in a layer is connected to every node in the next layer, leading to a high number of parameters. Freezing parts of the network can restrict how well the model adapts to new data, especially in terms of generalization.

# %%
for name, param in model.named_parameters():
    if param.requires_grad:
        print(f"Gradient of {name}: {param.grad}")
# Out:
# Gradient of backbone.predictor.0.weight: tensor([[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         ...,
#         [0.0000, 0.0008, 0.0005,  ..., 0.0003, 0.0007, 0.0007],
#         [0.0000, 0.0007, 0.0004,  ..., 0.0002, 0.0006, 0.0006],
#         [0.0000, 0.0005, 0.0003,  ..., 0.0002, 0.0004, 0.0004]],
#        device='cuda:0')
# Gradient of backbone.predictor.0.bias: tensor([0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 1.5752e-03,
#         0.0000e+00, 1.4733e-03, 0.0000e+00, 3.4588e-03, 0.0000e+00, 0.0000e+00,
#         3.2012e-03, 0.0000e+00, 0.0000e+00, 1.3422e-03, 1.7148e-04, 0.0000e+00,
#         8.6308e-04, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 2.5572e-03,
#         3.5903e-04, 4.1918e-03, 1.8127e-03, 6.4241e-03, 7.0385e-04, 1.5949e-04,
#         2.3083e-03, 0.0000e+00, 0.0000e+00, 0.0000e+00, 4.0759e-04, 4.8027e-03,
#         0.0000e+00, 2.1719e-03, 0.0000e+00, 8.6658e-05, 4.1435e-04, 0.0000e+00,
#         0.0000e+00, 3.5482e-04, 9.0486e-04, 8.0808e-03, 2.1038e-04, 0.0000e+00,
#         2.0678e-04, 3.9708e-03, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         1.8288e-04, 4.3357e-03, 5.9520e-03, 2.6244e-02, 0.0000e+00, 0.0000e+00,
#         5.9383e-04, 3.7280e-03, 3.1901e-03, 2.2601e-03], device='cuda:0')
# Gradient of backbone.predictor.2.weight: tensor([[0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0169, 0.0000, 0.0170, 0.0000,
#          0.0377, 0.0000, 0.0000, 0.0315, 0.0000, 0.0000, 0.0164, 0.0017, 0.0000,
#          0.0096, 0.0000, 0.0000, 0.0000, 0.0000, 0.0296, 0.0034, 0.0400, 0.0195,
#          0.0525, 0.0078, 0.0017, 0.0230, 0.0000, 0.0000, 0.0000, 0.0044, 0.0466,
#          0.0000, 0.0230, 0.0000, 0.0007, 0.0048, 0.0000, 0.0000, 0.0042, 0.0103,
#          0.0675, 0.0021, 0.0000, 0.0022, 0.0425, 0.0000, 0.0000, 0.0000, 0.0000,
#          0.0020, 0.0444, 0.0524, 0.2223, 0.0000, 0.0000, 0.0067, 0.0372, 0.0314,
#          0.0252]], device='cuda:0')
# Gradient of backbone.predictor.2.bias: tensor([0.1634], device='cuda:0')
